# %%
from views_dataviz.radar import plot_radar
import pandas as pd

# %%
mock = pd.DataFrame(
    {
        "metrics": ["score_a", "score_b", "score_c", "score_d"],
        "model_a": [0.8, 1.2, 0.2, 1.4],
        "model_b": [0.3, 1.5, 0.5, 0.4],
        "model_c": [1.5, 0.6, 1.2, 0.2]
    }
)

# %%
mock
# Out:
#    metrics  model_a  model_b  model_c
# 0  score_a      0.8      0.3      1.5
# 1  score_b      1.2      1.5      0.6
# 2  score_c      0.2      0.5      1.2
# 3  score_d      1.4      0.4      0.2

# %%
plot_radar(
    df=mock, 
    categories="metrics", 
    entries=["model_a", "model_b", "model_c"],
    fill=[True, True, False],
    colors=["Red", "Green", "Black"],
    tick_locations=[0.5, 1, 1.5, 2],
    label_size=14,
    minmax=(0,2),
    legend_anchor=(1.3, 1),
    legend_size=12,
    linewidth=2,
    title="Example",
)
